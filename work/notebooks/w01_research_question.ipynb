# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/prachichoudhary2004/FlyRank/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## My Lane and Why
#
# **Lane:** Refresh / Content Opportunity Scoring
#
# I chose the Refresh / Content Opportunity Scoring lane because the goal is to help SEO managers decide which content pages should be reviewed first. Instead of refreshing every page, I want to rank pages based on search and engagement signals so limited time can be spent on the pages with the highest potential impact.

# %% [markdown]
# ## The Question
#
# **Research Question**
#
# Which content pages should be prioritized for refresh based on their search and engagement signals?
#
# **Decision**
#
# Prioritize which pages should be reviewed first for content refresh.
#
# **Who acts?**
#
# SEO managers and content editors.
#
# **Action**
#
# Review, update, expand, rewrite, or monitor the highest-ranked pages.
#
# **Cost of a wrong recommendation**
#
# Reviewing low-value pages wastes editor time and resources, while missing an important page may result in continued traffic decline and lost search opportunities.
#
# **Why Data / ML Helps**
#
# Many factors influence page performance, including impressions, CTR, average position, content age, and engagement. A simple rule may miss interactions between these signals, while a ranking model can combine them to produce a better priority list.
#
# **Task Type**
#
# Ranking / Scoring
#
# **Success Metric**
#
# Precision@K (for example, Precision@20 or Precision@50), because the goal is to rank the best pages for review.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Quick Observations
#
# The starter dataset contains **(replace with output)** content pages. The average CTR is **(replace with output)**, and there are **(replace with output)** pages with zero impressions. These statistics indicate that page performance varies considerably, making it worthwhile to prioritize pages for review rather than treating all pages equally.

# %%
import pandas as pd
df = pd.read_csv("content_refresh_anonymized.csv")

print("Total Pages:", len(df))
print("Average CTR:", round(df["ctr"].mean(),3))
print("Average Search Volume:", round(df["search_volume"].mean(),2))
print("Pages with Zero Impressions:", (df["impressions_90d"]==0).sum())
# Out:
# Total Pages: 30000
# Average CTR: 0.511
# Average Search Volume: 158.88
# Pages with Zero Impressions: 0

# %% [markdown]
# ## Careful Words
#
# This work is intended to support content prioritization using observed search and engagement data. It does not prove that refreshing a page will increase traffic or that any signal causes better rankings. The results should be interpreted as decision-support and directional evidence rather than causal proof.

# %%
##

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
