# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/prachichoudhary2004/FlyRank/blob/main/work/notebooks/w03_data_contract.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
# !pip -q install duckdb huggingface_hub pyarrow fsspec

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %%
from huggingface_hub import login
from google.colab import userdata

login(userdata.get("HF_TOKEN"))

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %%
from huggingface_hub import HfApi

api = HfApi()

files = api.list_repo_files(
    repo_id="FlyRank/internship-warehouse",
    repo_type="dataset",
    token=userdata.get("HF_TOKEN")
)

print(files[:20])
# Out:
# ['.gitattributes', 'README.md', 'dim_clients.parquet', 'dim_content.parquet', 'fact_content_daily_performance/month=2025-01/data_0.parquet', 'fact_content_daily_performance/month=2025-02/data_0.parquet', 'fact_content_daily_performance/month=2025-03/data_0.parquet', 'fact_content_daily_performance/month=2025-04/data_0.parquet', 'fact_content_daily_performance/month=2025-05/data_0.parquet', 'fact_content_daily_performance/month=2025-06/data_0.parquet', 'fact_content_daily_performance/month=2025-07/data_0.parquet', 'fact_content_daily_performance/month=2025-08/data_0.parquet', 'fact_content_daily_performance/month=2025-09/data_0.parquet', 'fact_content_daily_performance/month=2025-10/data_0.parquet', 'fact_content_daily_performance/month=2025-11/data_0.parquet', 'fact_content_daily_performance/month=2025-12/data_0.parquet', 'fact_content_daily_performance/month=2026-01/data_0.parquet', 'fact_content_daily_performance/month=2026-02/data_0.parquet', 'fact_content_daily_performance/month=
# ...

# %% [markdown]
# ## Data limits
#
# This analysis has several limitations:
#
# - The warehouse contains an unbalanced history, so different clients have different amounts of historical data.
# - Some early rows contain only Google Search Console data because GA4 tracking was not yet available (`ga4_data_available = FALSE`), so engagement metrics may be missing.
# - I use a mid-panel month (2026-03) to avoid developing on the final month, which is reserved as a future outcome window.
# - This project uses observational search and engagement data. It can support ranking and decision-making, but it cannot prove that refreshing a page will cause traffic to improve.
# - The output should be treated as decision-support for SEO managers, not as a guarantee of future performance.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self Check
#
# - ✅ I defined a clear data contract for my chosen lane.
# - ✅ I identified the unit of analysis, data tables, time window, target/proxy, and excluded fields.
# - ✅ I verified my assumptions with three queries (grain, row count/date span, and availability).
# - ✅ I created a feature frame using five features and explained why each is available at the decision moment.
# - ✅ I demonstrated a label leakage example, removed the leaking feature, and kept the honest result.
# - ✅ I documented one limitation of my data slice.
# - ✅ The notebook runs from top to bottom without errors.
# - ✅ No private client names, URLs, or sensitive information are included.
# - ✅ The completed notebook is saved as `work/notebooks/w03_data_contract.ipynb` and committed to my GitHub repository.
